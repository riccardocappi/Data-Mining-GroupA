# %% [markdown]
# ### Import required libraries

# %%
import pandas as pd
from sklearn.preprocessing import OneHotEncoder

# %% [markdown]
# ### Import datasets

# %%
train = pd.read_csv("phone_train.csv")
test = pd.read_csv("phone_validation.csv")

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 99 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   tariff.plan          10000 non-null  int64
#  1   payment.method       10000 non-null  object
#  2   sex                  10000 non-null  object
#  3   age                  10000 non-null  float64
#  4   activation.zone      10000 non-null  int64
#  5   activation.channel   10000 non-null  int64
#  6   vas1                 10000 non-null  object
#  7   vas2                 10000 non-null  object
#  8   q01.out.ch.peak      10000 non-null  int64
#  9   q01.out.dur.peak     10000 non-null  int64
#  10  q01.out.val.peak     10000 non-null  float64
#  11  q01.out.ch.offpeak   10000 non-null  int64
#  12  q01.out.dur.offpeak  10000 non-null  int64
#  13  q01.out.val.offpeak  10000 non-null  float64
#  14  q01.in.ch.tot        10000 non-null  int64
#  15  q01.in.dur.tot       10000 non-null  int64
#  16  q01.ch.sms           10000 non-null  int64
#  17  q01.ch.cc            10000 non-null  int64
#  18  q02.out.ch.peak      10000 non-null  int64
#  19  q02.out.dur.peak     10000 non-null  int64
#  20  q02.out.val.peak     10000 non-null  float64
#  21  q02.out.ch.offpeak   10000 non-null  int64
#  22  q02.out.dur.offpeak  10000 non-null  int64
#  23  q02.out.val.offpeak  10000 non-null  float64
#  24  q02.in.ch.tot        10000 non-null  int64
#  25  q02.in.dur.tot       10000 non-null  int64
#  26  q02.ch.sms           10000 non-null  int64
#  27  q02.ch.cc            10000 non-null  int64
#  28  q03.out.ch.peak      10000 non-null  int64
#  29  q03.out.dur.peak     10000 non-null  int64
#  30  q03.out.val.peak     10000 non-null  float64
#  31  q03.out.ch.offpeak   10000 non-null  int64
#  32  q03.out.dur.offpeak  10000 non-null  int64
#  33  q03.out.val.offpeak  10000 non-null  float64
#  34  q03.in.ch.tot        10000 non-null  int64
#  35  q03.in.dur.tot       10000 non-null  int64
#  36  q03.ch.sms           10000 non-null  int64
#  37  q03.ch.cc            10000 non-null  int64
#  38  q04.out.ch.peak      10000 non-null  int64
#  39  q04.out.dur.peak     10000 non-null  int64
#  40  q04.out.val.peak     10000 non-null  float64
#  41  q04.out.ch.offpeak   10000 non-null  int64
#  42  q04.out.dur.offpeak  10000 non-null  int64
#  43  q04.out.val.offpeak  10000 non-null  float64
#  44  q04.in.ch.tot        10000 non-null  int64
#  45  q04.in.dur.tot       10000 non-null  int64
#  46  q04.ch.sms           10000 non-null  int64
#  47  q04.ch.cc            10000 non-null  int64
#  48  q05.out.ch.peak      10000 non-null  int64
#  49  q05.out.dur.peak     10000 non-null  int64
#  50  q05.out.val.peak     10000 non-null  float64
#  51  q05.out.ch.offpeak   10000 non-null  int64
#  52  q05.out.dur.offpeak  10000 non-null  int64
#  53  q05.out.val.offpeak  10000 non-null  float64
#  54  q05.in.ch.tot        10000 non-null  int64
#  55  q05.in.dur.tot       10000 non-null  int64
#  56  q05.ch.sms           10000 non-null  int64
#  57  q05.ch.cc            10000 non-null  int64
#  58  q06.out.ch.peak      10000 non-null  int64
#  59  q06.out.dur.peak     10000 non-null  int64
#  60  q06.out.val.peak     10000 non-null  float64
#  61  q06.out.ch.offpeak   10000 non-null  int64
#  62  q06.out.dur.offpeak  10000 non-null  int64
#  63  q06.out.val.offpeak  10000 non-null  float64
#  64  q06.in.ch.tot        10000 non-null  int64
#  65  q06.in.dur.tot       10000 non-null  int64
#  66  q06.ch.sms           10000 non-null  int64
#  67  q06.ch.cc            10000 non-null  int64
#  68  q07.out.ch.peak      10000 non-null  int64
#  69  q07.out.dur.peak     10000 non-null  int64
#  70  q07.out.val.peak     10000 non-null  float64
#  71  q07.out.ch.offpeak   10000 non-null  int64
#  72  q07.out.dur.offpeak  10000 non-null  int64
#  73  q07.out.val.offpeak  10000 non-null  float64
#  74  q07.in.ch.tot        10000 non-null  int64
#  75  q07.in.dur.tot       10000 non-null  int64
#  76  q07.ch.sms           10000 non-null  int64
#  77  q07.ch.cc            10000 non-null  int64
#  78  q08.out.ch.peak      10000 non-null  int64
#  79  q08.out.dur.peak     10000 non-null  int64
#  80  q08.out.val.peak     10000 non-null  float64
#  81  q08.out.ch.offpeak   10000 non-null  int64
#  82  q08.out.dur.offpeak  10000 non-null  int64
#  83  q08.out.val.offpeak  10000 non-null  float64
#  84  q08.in.ch.tot        10000 non-null  int64
#  85  q08.in.dur.tot       10000 non-null  int64
#  86  q08.ch.sms           10000 non-null  int64
#  87  q08.ch.cc            10000 non-null  int64
#  88  q09.out.ch.peak      10000 non-null  int64
#  89  q09.out.dur.peak     10000 non-null  int64
#  90  q09.out.val.peak     10000 non-null  float64
#  91  q09.out.ch.offpeak   10000 non-null  int64
#  92  q09.out.dur.offpeak  10000 non-null  int64
#  93  q09.out.val.offpeak  10000 non-null  float64
#  94  q09.in.ch.tot        10000 non-null  int64
#  95  q09.in.dur.tot       10000 non-null  int64
#  96  q09.ch.sms           10000 non-null  int64
#  97  q09.ch.cc            10000 non-null  int64
#  98  y                    10000 non-null  int64
# dtypes: float64(19), int64(76), object(4)
# memory usage: 7.6+ MB

# %%
#Checking for null values
is_null = train.isna()
is_null
# Out:
#       tariff.plan  payment.method    sex    age  activation.zone  \
# 0           False           False  False  False            False
# 1           False           False  False  False            False
# 2           False           False  False  False            False
# 3           False           False  False  False            False
# 4           False           False  False  False            False
# ...           ...             ...    ...    ...              ...
# 9995        False           False  False  False            False
# 9996        False           False  False  False            False
# 9997        False           False  False  False            False
# 9998        False           False  False  False            False
# 9999        False           False  False  False            False
#
#       activation.channel   vas1   vas2  q01.out.ch.peak  q01.out.dur.peak  \
# 0                  False  False  False            False             False
# 1                  False  False  False            False             False
# 2                  False  False  False            False             False
# 3                  False  False  False            False             False
# 4                  False  False  False            False             False
# ...                  ...    ...    ...              ...               ...
# 9995               False  False  False            False             False
# 9996               False  False  False            False             False
# 9997               False  False  False            False             False
# 9998               False  False  False            False             False
# 9999               False  False  False            False             False
#
#       ...  q09.out.dur.peak  q09.out.val.peak  q09.out.ch.offpeak  \
# 0     ...             False             False               False
# 1     ...             False             False               False
# 2     ...             False             False               False
# 3     ...             False             False               False
# 4     ...             False             False               False
# ...   ...               ...               ...                 ...
# 9995  ...             False             False               False
# 9996  ...             False             False               False
# 9997  ...             False             False               False
# 9998  ...             False             False               False
# 9999  ...             False             False               False
#
#       q09.out.dur.offpeak  q09.out.val.offpeak  q09.in.ch.tot  q09.in.dur.tot  \
# 0                   False                False          False           False
# 1                   False                False          False           False
# 2                   False                False          False           False
# 3                   False                False          False           False
# 4                   False                False          False           False
# ...                   ...                  ...            ...             ...
# 9995                False                False          False           False
# 9996                False                False          False           False
# 9997                False                False          False           False
# 9998                False                False          False           False
# 9999                False                False          False           False
#
#       q09.ch.sms  q09.ch.cc      y
# 0          False      False  False
# 1          False      False  False
# 2          False      False  False
# 3          False      False  False
# 4          False      False  False
# ...          ...        ...    ...
# 9995       False      False  False
# 9996       False      False  False
# 9997       False      False  False
# 9998       False      False  False
# 9999       False      False  False
#
# [10000 rows x 99 columns]

# %%
summary_stats = train.describe()

activation_zone_summary = train['activation.zone'].describe()

print(activation_zone_summary)
# Out:
# count    10000.000000
# mean         2.071600
# std          0.980495
# min          1.000000
# 25%          1.000000
# 50%          2.000000
# 75%          3.000000
# max          4.000000
# Name: activation.zone, dtype: float64

# %%
activation_channel_summary = train['activation.channel'].describe()
print(activation_channel_summary)
# Out:
# count    10000.000000
# mean         5.601000
# std          1.585576
# min          2.000000
# 25%          5.000000
# 50%          5.000000
# 75%          5.000000
# max          9.000000
# Name: activation.channel, dtype: float64

# %%
column_types = train.dtypes

# Get the categorical variables
categorical_features = column_types[column_types == 'object'].index.tolist()

#categorical_numeric_features = ["activation.zone"]
#categorical_features += categorical_numeric_features

for feature in categorical_features:
    print(feature)
    print(train[feature].value_counts())
# Out:
# payment.method
# payment.method
# Carta di Credito           4779
# Domiciliazione Bancaria    3635
# Bollettino Postale         1586
# Name: count, dtype: int64
# sex
# sex
# B    5266
# M    3704
# F    1030
# Name: count, dtype: int64
# vas1
# vas1
# N    7509
# Y    2491
# Name: count, dtype: int64
# vas2
# vas2
# N    9362
# Y     638
# Name: count, dtype: int64

# %%
# Removes from X the specified features
def rm_feature(X, omitted_features):
    X = X.drop(columns=omitted_features)
    return X

# %%
def one_hot_encoding(X):
    # One-hot encoding features
  
    # We need to decide if we want to encode also activation.zone and 
    # activation.channel, because in the test set there are entries with 
    # activation.zone = 0, while in the training set the min value for it is 1
    # Therefore, the fit on the test set won't work.

    #X[categorical_numeric_features] = X[categorical_numeric_features].astype(str)
    
    encoded_X = pd.get_dummies(X, columns=categorical_features,dtype=int)

    X_one_hot = X.drop(columns=categorical_features)

    X_one_hot = pd.concat([X_one_hot, encoded_X], axis=1)

    return X_one_hot

# %%
X_train = one_hot_encoding(train)
X_test = one_hot_encoding(test)

y = X_train['y']
